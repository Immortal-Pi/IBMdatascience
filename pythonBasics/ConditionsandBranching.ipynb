# %% [markdown]
# # basic so doing only the quiz
# ![image.png](attachment:76058685-ac00-49cc-81a0-99b081dcc7ea.png)

# %% [markdown]
# # compare characters
# ![image.png](attachment:69f9ce5b-1eff-43d7-b2df-dca6557db237.png)

# %%
'BA'>'AB', 'B'<'A'
# Out:
# (True, False)

# %% [markdown]
# # quiz on conditions

# %%
rating = 8.5
if rating > 8:
    print ("This album is Amazing!")
# Out:
# This album is Amazing!

# %%
rating = 5
if rating > 8:
    print ("This album is Amazing!")
elif rating <8:
    print('this album is ok')
# Out:
# this album is ok

# %%
album_year = 1979

if album_year < 1980 or album_year == 1991 or album_year == 1993:
    print("This album came out in year", album_year)
# Out:
# This album came out in year 1979

# %%
'a'=='A'
# Out:
# False
