# %% [markdown]
# # HTTP Request and Response

# %%
import requests

# %%
url='https://www.ibm.com/'
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
response=r.headers

# %%
response['date']
# Out:
# 'Thu, 18 Apr 2024 06:18:47 GMT'

# %%
response['Content-Type']
# Out:
# ('text/html;charset=utf-8',
#  'utf-8',
# ...

# %%
 r.encoding
# Out:
# 'utf-8'

# %%
 r.text
# Out:
# '\n<!DOCTYPE HTML>\n<html lang="en-in">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    <meta charset="UTF-8"/>\r\n    <meta name="languageCode" content="en"/>\r\n    <meta name="countryCode" content="in"/>\r\n    <meta name="searchTitle" content="IBM - India"/>\r\n    <meta name="focusArea" content="Cross IBM - All"/>\r\n    <title>IBM - India</title>\r\n    <link rel="icon" href="/content/dam/adobe-cms/default-images/favicon.svg"/>\r\n    \r\n    <meta name="description" content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow."/>\r\n    <meta name="template" content="full-width-layout"/>\r\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\r\n    <meta name="robots" content="index, follow"/>\r\n    \r\n    <link rel="canonical" href="https://www.ibm.com/in-en"/>\r\n    <style id="anti-flicker-style">\r\n        :not(:defined) {\r\n          visibility
# ...

# %% [markdown]
# # Get Request with URL parameters
# ![image.png](attachment:07e736ff-732b-42ae-83b9-5057fd1b3785.png)
# ![image.png](attachment:11062a7d-cb5c-4878-b89d-003513da5a66.png)

# %%
name='Joseph'
ID='123'
url_get='http://httpbin.org/get'
payload={'name':name,'ID':ID}

# %%
r=requests.get(url_get,params=payload)
print(r.request.body)
r_json=r.text
print(r_json)
# Out:
# None
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-6620bd00-3b7bc83e4a42c7664b6e84c1"
#   },
#   "origin": "103.5.134.178",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %% [markdown]
# # Post Requests

# %%
url_get='http://httpbin.org/post'
payload={'name':'Amruth Pai','ID':'007'}
r=requests.get(url_get,params=payload)
r.status_code
# Out:
# 405

# %% [markdown]
# # web scraping (extracting information from websites or web pages)
#     - HTTP Requests
#     - web page retrieval
#     - HTML parsing
#     - Data extraction
#     - Data transformation
#     - Storage
#     - Automation

# %% [markdown]
# # HTML structure
# ![image.png](attachment:afb27a6c-6e4e-4fb2-a1d7-02e2d86fdcf1.png)
# ![image.png](attachment:680aed96-a1a8-4c9c-b52f-7a3b126bf683.png)
# ![image.png](attachment:d899bdc9-baf2-4e8f-85c4-ee82ab213f7e.png)

# %% [markdown]
# # Web scraping

# %%
from bs4 import BeautifulSoup

# %%
url='https://en.wikipedia.org/wiki/IBM'
r=requests.get(url)
r.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>IBM - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-featu
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>IBM - Wikipedia</title>
# ...

# %%
links = soup.find_all('a')
for link in links:
    print(link.text)
# Out:
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Donate
# Help
# Learn to edit
# Community portal
# Recent changes
# Upload file
#
#
#
#
#
#
#
#
# Search
#
# Create account
# Log in
#  Create account
#  Log in
# learn more
# Contributions
# Talk
#
# (Top)
#
#
#
# 1History
#
#
#
# 2Corporate affairs
#
#
#
# 2.1Business trends
#
#
#
# 2.2Headquarters and offices
#
#
#
# 3Products and services
#
#
#
# 4Research
#
#
#
# 5Brand and reputation
#
#
#
# 6People and culture
#
#
#
# 6.1Employees
#
#
#
# 6.1.1IBM alumni
#
#
#
# 6.2Board and shareholders
#
#
#
# 7See also
#
#
#
# 8Notes
#
#
#
# 9References
#
#
#
# 10Further reading
#
#
#
# 11External links
#
# Afrikaans
# Alemannisch
# العربية
# Asturianu
# Azərbaycanca
# تۆرکجه
# বাংলা
# Bân-lâm-gú
# Башҡортса
# Беларуская
# Беларуская (тарашкевіца)
# Български
# Bosanski
# Català
# Чӑвашла
# Čeština
# Dansk
# Deutsch
# Eesti
# Ελληνικά
# Español
# Esperanto
# Euskara
# فارسی
# Français
# ...

# %%
# download a file
url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'

# %%
r=requests.get(url)
with open('datasets/httpResponse.txt','wb') as file:
    file.write(r.content)

# %% [markdown]
# # API Example
# # Random User and Fruityvice API
# ![image.png](attachment:2b34f8ad-6267-46b7-a3da-f9595fba9283.png)

# %% [markdown]
# ## Example 1: RandomUser API
# ![image.png](attachment:c69cfea2-8134-4012-ab11-41496ad31583.png)

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r= RandomUser()
some_list=r.generate_users(10)

# %%
name=r.get_full_name()

# %%
name
# Out:
# 'Fatima Hidalgo'

# %%
for user in some_list:
    print(user.get_full_name()," ",user.get_email())
# Out:
# Ümit Ozansoy   umit.ozansoy@example.com
# Marcus Rasmussen   marcus.rasmussen@example.com
# Andrew Holland   andrew.holland@example.com
# Asmaa Touw   asmaa.touw@example.com
# Nieves Carmona   nieves.carmona@example.com
# Terry Ferguson   terry.ferguson@example.com
# Latife Tuğluk   latife.tugluk@example.com
# Milla Kurtti   milla.kurtti@example.com
# Albana Oliveira   albana.oliveira@example.com
# Christopher Lopez   christopher.lopez@example.com

# %% [markdown]
# # Exercise 1

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/47.jpg
# https://randomuser.me/api/portraits/men/89.jpg
# https://randomuser.me/api/portraits/men/46.jpg
# https://randomuser.me/api/portraits/women/8.jpg
# https://randomuser.me/api/portraits/women/21.jpg
# https://randomuser.me/api/portraits/men/64.jpg
# https://randomuser.me/api/portraits/women/89.jpg
# https://randomuser.me/api/portraits/women/46.jpg
# https://randomuser.me/api/portraits/women/14.jpg
# https://randomuser.me/api/portraits/men/9.jpg

# %%
def get_users():
    users=[]
    for user in RandomUser.generate_users(10):
        users.append({'Name':user.get_full_name(),'Gender':user.get_gender(),'City':user.get_city(),'State':user.get_state(),'Email':user.get_email(), 'DOB':user.get_dob(),'Picture':user.get_picture()})
    return pd.DataFrame(users)

# %%
result=get_users()

# %%
result
# Out:
#                 Name  Gender                   City  \
# 0     Jolanda Klocke  female             Nördlingen
# 1     Annika Brodahl  female                Raufoss
# 2           Elsa Roy  female      Casti-Wergenstein
# 3  Alejandro Alvarez    male                  Parla
# 4          Tilo Kern    male                  Peitz
# 5    Mireille Moreau  female  Affoltern im Emmental
# 6       Sofia Davies  female             Upper Hutt
# 7   Mauri Nascimento    male               Anápolis
# 8       Cody Carlson    male                 Darwin
# 9    Kuzey Hamzaoğlu    male                Bilecik
#
#                           State                          Email  \
# 0                      Saarland     jolanda.klocke@example.com
# 1                       Hedmark     annika.brodahl@example.com
# 2                          Bern           elsa.roy@example.com
# 3                        Aragón  alejandro.alvarez@example.com
# 4                       Sachsen          tilo.kern@example.com
# ...

# %% [markdown]
# # Example 2 : Fruityvice API

# %%
import requests 
import json

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")
data_json=json.loads(data.text)
df=pd.DataFrame(data_json)
df
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df2 = pd.json_normalize(data_json)
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
cherry=df2.loc[df2['name']=='Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# # Exercise 2

# %%
banana=df2.loc[df2['name']=='Banana']
banana
# Out:
#      name  id    family         order genus  nutritions.calories  \
# 2  Banana   1  Musaceae  Zingiberales  Musa                   96
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 2             0.2              17.2                      22.0
#
#    nutritions.protein
# 2                 1.0

# %%
banana.iloc[0,5]
# Out:
# 96

# %% [markdown]
# # Exercise 3

# %%
url='https://official-joke-api.appspot.com/jokes/ten'

# %%
data=requests.get(url)
data_json=json.loads(data.text)
data_json
# Out:
# [{'type': 'general',
#   'setup': 'How many tickles does it take to tickle an octopus?',
#   'punchline': 'Ten-tickles!',
#   'id': 145},
#  {'type': 'general',
#   'setup': 'What did the spaghetti say to the other spaghetti?',
#   'punchline': 'Pasta la vista, baby!',
#   'id': 150},
#  {'type': 'general',
#   'setup': "What's the worst part about being a cross-eyed teacher?",
#   'punchline': "They can't control their pupils.",
#   'id': 278},
#  {'type': 'general',
#   'setup': 'Why did the butcher work extra hours at the shop?',
#   'punchline': 'To make ends meat.',
#   'id': 63},
#  {'type': 'general',
#   'setup': 'Why does Waldo only wear stripes?',
#   'punchline': "Because he doesn't want to be spotted.",
#   'id': 395},
#  {'type': 'general',
#   'setup': 'How come the stadium got hot after the game?',
#   'punchline': 'Because all of the fans left.',
#   'id': 116},
#  {'type': 'general',
#   'setup': "I'm reading a book about anti-gravity...",
# ...

# %%
df2=pd.DataFrame(data_json)
df2
# Out:
#       type                                              setup  \
# 0  general  How many tickles does it take to tickle an oct...
# 1  general  What did the spaghetti say to the other spaghe...
# 2  general  What's the worst part about being a cross-eyed...
# 3  general  Why did the butcher work extra hours at the shop?
# 4  general                  Why does Waldo only wear stripes?
# 5  general       How come the stadium got hot after the game?
# 6  general           I'm reading a book about anti-gravity...
# 7  general              How does a French skeleton say hello?
# 8  general                 What’s 50 Cent’s name in Zimbabwe?
# 9  general                          What is this movie about?
#
#                                 punchline   id
# 0                            Ten-tickles!  145
# 1                   Pasta la vista, baby!  150
# 2        They can't control their pupils.  278
# 3                      To make ends meat.   63
# ...

# %%
df2.drop(columns=['type','id'])
# Out:
#                                                setup  \
# 0  How many tickles does it take to tickle an oct...
# 1  What did the spaghetti say to the other spaghe...
# 2  What's the worst part about being a cross-eyed...
# 3  Why did the butcher work extra hours at the shop?
# 4                  Why does Waldo only wear stripes?
# 5       How come the stadium got hot after the game?
# 6           I'm reading a book about anti-gravity...
# 7              How does a French skeleton say hello?
# 8                 What’s 50 Cent’s name in Zimbabwe?
# 9                          What is this movie about?
#
#                                 punchline
# 0                            Ten-tickles!
# 1                   Pasta la vista, baby!
# 2        They can't control their pupils.
# 3                      To make ends meat.
# 4  Because he doesn't want to be spotted.
# 5           Because all of the fans left.
# 6             It's impossible to put down
# ...

# %% [markdown]
# # HTML for web scraping
# ![image.png](attachment:1cea2426-dc71-427a-8820-9c711b850067.png)
# # HTML anchor tag
# ![image.png](attachment:d0792063-0c86-46d1-8756-5651920c12cf.png)
