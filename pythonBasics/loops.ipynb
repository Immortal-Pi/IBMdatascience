# %% [markdown]
# # Loops
# - for
# - while

# %% [markdown]
# ## for loop
# ![image.png](attachment:0f50cefa-f016-47f5-991b-c7228e140716.png)

# %% [markdown]
# ## range for loop

# %%
for i in range(5):
    print(square[i])
# Out:
# red
# yellow
# green
# purple
# blue

# %%
square=['red','yellow','green','purple','blue']
for i in square:
    print(i)
# Out:
# red
# yellow
# green
# purple
# blue

# %% [markdown]
# ##  enumerate for loop

# %%
for index, color in enumerate(square):
    print(f'{index},{color}')
# Out:
# 0,red
# 1,yellow
# 2,green
# 3,purple
# 4,blue

# %% [markdown]
# # while loop
# ![image.png](attachment:f34669cf-9a58-427e-b764-eafa6427fe01.png)

# %%
i=0
while(square[i]!='purple'):
    print(square[i])
    i=i+1
# Out:
# red
# yellow
# green

# %% [markdown]
# # practise exercise on loops

# %%
for i in range(-4,5):
    print(i)
# Out:
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %%
Genres=[ 'rock', 'R&B', 'Soundtrack', 'R&B', 'soul', 'pop']
for genres in Genres:
    print(genres)
# Out:
# rock
# R&B
# Soundtrack
# R&B
# soul
# pop

# %%
PlayListRatings = [10, 9.5, 10, 8, 7.5, 5, 10, 10]
i=0
while (PlayListRatings[i]>6 and i<len(PlayListRatings)):
    print(PlayListRatings[i])
    i+=1
# Out:
# 10
# 9.5
# 10
# 8
# 7.5

# %%
 square = ['orange', 'orange', 'purple', 'blue ', 'orange']
new_square = []

# %%
i=0
while(square[i]=='orange' and i<len(square)):
    new_square.append(square[i])
    i=i+1
new_square
# Out:
# ['orange', 'orange']

# %% [markdown]
# # real life problems

# %%
n1 = 6
for i in range(1,11):
    print(f'{n1}x{i}={n1*i}')
n1 = 7
for i in range(1,11):
    print(f'{n1}x{i}={n1*i}')
# Out:
# 6x1=6
# 6x2=12
# 6x3=18
# 6x4=24
# 6x5=30
# 6x6=36
# 6x7=42
# 6x8=48
# 6x9=54
# 6x10=60
# 7x1=7
# 7x2=14
# 7x3=21
# 7x4=28
# 7x5=35
# 7x6=42
# 7x7=49
# 7x8=56
# 7x9=63
# 7x10=70

# %%
Animals = ["lion", "giraffe", "gorilla", "parrots", "crocodile","deer", "swan"]
# animals_order=sorted(Animals)
# print(animals_order)
i=0
new=[]
while i<len(Animals):
    if (len(Animals[i])==7):
        new.append(Animals[i])
    i+=1
new
# Out:
# ['giraffe', 'gorilla', 'parrots']
