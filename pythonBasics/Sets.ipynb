# %% [markdown]
# # Sets

# %%
set1={"pop","rock","hard rock", "rock","R&B" }
set1
# Out:
# {'R&B', 'hard rock', 'pop', 'rock'}

# %%
set1.add('AC/DC')
set1
# Out:
# {'AC/DC', 'R&B', 'hard rock', 'pop', 'rock'}

# %%
set1.remove('rock')
set1
# Out:
# {'AC/DC', 'R&B', 'hard rock', 'pop'}

# %%
# verify if the element is present in set
'hard rock' in set1
# Out:
# True

# %%
# convert list to set
album_list = [ "Michael Jackson", "Thriller", 1982, "00:42:19", \
              "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]
album_set = set(album_list)             
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %% [markdown]
# # intersection of sets
# ![image.png](attachment:41ea74f4-c4f2-4a9e-9665-fd422a9173d9.png)

# %%
album_set_1={"AC/DC","Back in Black",'Thriller'}
album_set_2={"AC/DC","Back in Black",'The Dark Side of the Moon'}

# %%
# intersection
album_set_1 & album_set_2
# Out:
# {'AC/DC', 'Back in Black'}

# %%
# difference
album_set_1.difference(album_set_2)
# Out:
# {'Thriller'}

# %% [markdown]
# ![image.png](attachment:84925920-b1cc-425d-8d43-495a537565a3.png)

# %%
# union
album_set_1.union(album_set_2)
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %%
# is a subset 
album_set_3={'AC/DC','Back in Black'}
album_set_3.issubset(album_set_1)
# Out:
# True

# %%
# is a superset
album_set_1.issuperset(album_set_3)
# Out:
# True

# %% [markdown]
# # Quiz

# %%
set1 = set(['rap','house','electronic music', 'rap'])
set1
# Out:
# {'electronic music', 'house', 'rap'}

# %%
A = [1, 2, 2, 1]
B = set([1, 2, 2, 1])
sum(A)==sum(B)
# Out:
# False

# %%
album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])

# %%
album_set3=album_set1&album_set2
album_set3
# Out:
# {'AC/DC', 'Back in Black'}

# %%
album_set1.issubset(album_set3)
# Out:
# False

# %%
a=[1,2,3,4]
del(a[0])
a
# Out:
# [2, 3, 4]

# %%
len(("disco",10,1.2, "hard rock",10))
# Out:
# 5
