# %% [markdown]
# # Web scraping
# ![image.png](attachment:67eded59-2db3-450d-9bc7-dfb95a2435e0.png)

# %%
from bs4 import BeautifulSoup
import requests
URL = "http://www.example.com"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

# %%
import scrapy
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = ['http://quotes.toscrape.com/tag/humor/',]
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {'quote': quote.css('span.text::text').get()}

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("http://www.linkedin.com")

# %% [markdown]
# # Web scrapping using pandas

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_largest_banks'

# %%
import pandas as pd
URL = 'https://en.wikipedia.org/wiki/List_of_largest_banks'
tables = pd.read_html(URL)
df = tables[0]
print(df)
# Out:
#    Rank                                Bank name  Market cap (US$ billion)
# 0     1                           JPMorgan Chase                    491.76
# 1     2                          Bank of America                    266.45
# 2     3  Industrial and Commercial Bank of China                    219.45
# 3     4                              Wells Fargo                    178.74
# 4     5               Agricultural Bank of China                    175.69
# 5     6                                HDFC Bank                    169.84
# 6     7                        HSBC Holdings PLC                    156.13
# 7     8                           Morgan Stanley                    153.05
# 8     9                  China Construction Bank                    151.97
# 9    10                            Bank of China                    150.39

# %%
URL = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'

# %%
import pandas as pd
URL = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
tables = pd.read_html(URL)
df = tables[2] # the required table will have index 2
print(df)
# Out:
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Forecast       Year       Estimate
# 0               World         —  109529216       2024      100562011
# 1       United States  Americas   28781083       2024       25462700
# 2               China      Asia   18532633  2024[n 1]       17963171
# 3             Germany    Europe    4591100       2024        4072192
# 4               Japan      Asia    4110452       2024        4231141
# ..                ...       ...        ...        ...            ...
# 208  Marshall Islands   Oceania        305       2024            280
# 209          Anguilla  Americas          —          —              —
# 210             Nauru   Oceania        161       2024            151
# 211        Montserrat  Americas          —          —              —
# 212            Tuvalu   Oceania         66       2024             60
#
#                United Nations[15]
#           Year           Estimate       Year
# 0         2022           96698005       2021
# 1         2022           23315081       2021
# 2    2022[n 3]           17734131  2021[n 1]
# 3         2022            4259935       2021
# 4         2022            4940878       2021
# ..         ...                ...        ...
# 208       2022                257       2021
# 209          —                303       2021
# 210       2022                155       2021
# 211          —                 72       2021
# 212       2022                 60       2021
#
# [213 rows x 8 columns]
